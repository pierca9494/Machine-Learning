# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# Caricamento del dataset Wine
data = load_diabetes()
X, y = data.data, data.target
#descrizione modello
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
df = pd.DataFrame(data=data.data, columns=data.feature_names)
display(df)
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018114  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046883  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044529 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
df['target']= data.target

# %%
display(df)
# Out:
#           age       sex       bmi  ...        s5        s6  target
# 0    0.038076  0.050680  0.061696  ...  0.019907 -0.017646   151.0
# 1   -0.001882 -0.044642 -0.051474  ... -0.068332 -0.092204    75.0
# 2    0.085299  0.050680  0.044451  ...  0.002861 -0.025930   141.0
# 3   -0.089063 -0.044642 -0.011595  ...  0.022688 -0.009362   206.0
# 4    0.005383 -0.044642 -0.036385  ... -0.031988 -0.046641   135.0
# ..        ...       ...       ...  ...       ...       ...     ...
# 437  0.041708  0.050680  0.019662  ...  0.031193  0.007207   178.0
# 438 -0.005515  0.050680 -0.015906  ... -0.018114  0.044485   104.0
# 439  0.041708  0.050680 -0.015906  ... -0.046883  0.015491   132.0
# 440 -0.045472 -0.044642  0.039062  ...  0.044529 -0.025930   220.0
# 441 -0.045472 -0.044642 -0.073030  ... -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %%
df.describe()
# Out:
#                 age           sex  ...            s6      target
# count  4.420000e+02  4.420000e+02  ...  4.420000e+02  442.000000
# mean  -2.511817e-19  1.230790e-17  ...  1.130318e-17  152.133484
# std    4.761905e-02  4.761905e-02  ...  4.761905e-02   77.093005
# min   -1.072256e-01 -4.464164e-02  ... -1.377672e-01   25.000000
# 25%   -3.729927e-02 -4.464164e-02  ... -3.317903e-02   87.000000
# 50%    5.383060e-03 -4.464164e-02  ... -1.077698e-03  140.500000
# 75%    3.807591e-02  5.068012e-02  ...  2.791705e-02  211.500000
# max    1.107267e-01  5.068012e-02  ...  1.356118e-01  346.000000
#
# [8 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA()),
    ('lr', LinearRegression())
])

# %%
param_distibutions = {
    'pca__n_components': np.arange(2,11)
       
}

# %%
skf = StratifiedKFold(n_splits= 2, shuffle= True, random_state= 42 )

# %%
grid_search = GridSearchCV(
    pipeline,
    verbose=2,
    
    cv = skf,
    
    param_grid=param_distibutions
    )

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ................................pca__n_components=2; total time=   0.0s
# [CV] END ................................pca__n_components=2; total time=   0.0s
# [CV] END ................................pca__n_components=3; total time=   0.0s
# [CV] END ................................pca__n_components=3; total time=   0.0s
# [CV] END ................................pca__n_components=4; total time=   0.0s
# [CV] END ................................pca__n_components=4; total time=   0.0s
# /home/piercarlo-ciraselli/Documents/GitHub/Machine-Learning/.venv/lib/python3.12/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# [CV] END ................................pca__n_components=5; total time=   0.0s
# [CV] END ................................pca__n_components=5; total time=   0.1s
# [CV] END ................................pca__n_components=6; total time=   0.0s
# [CV] END ................................pca__n_components=6; total time=   0.0s
# [CV] END ................................pca__n_components=7; total time=   0.0s
# [CV] END ................................pca__n_components=7; total time=   0.0s
# [CV] END ................................pca__n_components=8; total time=   0.0s
# [CV] END ................................pca__n_components=8; total time=   0.0s
# [CV] END ................................pca__n_components=9; total time=   0.0s
# [CV] END ................................pca__n_components=9; total time=   0.0s
# [CV] END ...............................pca__n_components=10; total time=   0.0s
# [CV] END ...............................pca__n_components=10; total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=2, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('pca', PCA()),
#                                        ('lr', LinearRegression())]),
#              param_grid={'pca__n_components': array([ 2,  3,  4,  5,  6,  7,  8,  9, 10])},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('pca', PCA(n_components=np.int64(6))),
#                 ('lr', LinearRegression())])

# %%
model_opt = grid_search.best_estimator_

model_opt.fit(X_train, y_train)

y_pred_new = model_opt.predict(X_test)

# %%
y_pred_train = model_opt.predict(X_train)

# %%
mean_squared_error(y_train, y_pred_train)
# Out:
# np.float64(2933.4370134870383)

# %%
r2_score(y_train, y_pred_train)
# Out:
# 0.5035258220978095

# %%
mean_squared_error(y_test, y_pred_new)
# Out:
# np.float64(2823.9622767868045)

# %%
r2_score(y_test, y_pred_new)
# Out:
# 0.5383331938965714
